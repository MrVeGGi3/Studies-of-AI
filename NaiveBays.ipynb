# %% [markdown]
# <a href="https://colab.research.google.com/github/MrVeGGi3/Studies-of-AI/blob/main/NaiveBays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from yellowbrick.classifier import ConfusionMatrix

# %%
# !pip install pandas

# %%
ficha = pd.read_csv('insurance.csv')
ficha
# Out:
#       ,"GoodStudent","Age","SocioEcon","RiskAversion","VehicleYear","ThisCarDam","RuggedAuto","Accident","MakeModel","DrivQuality","Mileage","Antilock","DrivingSkill","SeniorTrain","ThisCarCost","Theft","CarValue","HomeBase","AntiTheft","PropCost","OtherCarCost","OtherCar","MedCost","Cushioning","Airbag","ILiCost","DrivHist"
# 0      1,"False","Adult","Prole","Adventurous","Older...
# 1      2,"False","Senior","Prole","Cautious","Current...
# 2      3,"False","Senior","UpperMiddle","Psychopath",...
# 3      4,"False","Adolescent","Middle","Normal","Olde...
# 4      5,"False","Adolescent","Prole","Normal","Older...
# ...                                                  ...
# 19994  19996,"False","Adult","Prole","Adventurous","O...
# 19995  19997,"False","Adult","Middle","Normal","Older...
# 19996  19998,"False","Senior","UpperMiddle","Normal",...
# 19997  19999,"False","Adult","Middle","Normal","Older...
# 19998  20000,"False","Adult","Middle","Normal","Older...
#
# ...

# %%
ficha = ficha.drop(columns= ['Unnamed: 0'])
ficha
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-34346d3e77ed> in <cell line: 1>()
# ----> 1 ficha = ficha.drop(columns= ['Unnamed: 0'])
#       2 ficha
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
ficha.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-999be17be510> in <cell line: 1>()
# ----> 1 ficha.shape()
#
# TypeError: 'tuple' object is not callable
